# %%
import glob
# import onnxruntime
import torch
import os
import sys
import numpy as np
import pcdet
import tensorrt as trt
import pycuda.driver as cuda
import pycuda.autoinit
from PIL import Image
import numpy as np
import onnx
import matplotlib.pyplot as plt
from time import time
import argparse 
from det3d.torchie import Config

# %%
class Args:
    config='waymo_centerpoint_pp_two_pfn_stride1_3x.py'
    pfe_onnx_path = "pfe.onnx"
    rpn_onnx_path = "rpn.onnx"
    pfe_engine_path = "pfe_fp.engine"
    rpn_engine_path = "rpn_quant.engine"
    quant= True
    calib_file_path = '/mnt/data/waymo_opensets/val/tmp/calibrations/'
    calib_batch_size=1
args = Args()

# %%
cfg = Config.fromfile(args.config)

if args.quant :
    calib_files = glob.glob(os.path.join(args.calib_file_path, "*bin") )
    print("%d calib files for each model. " % (len(calib_files)//2) )
    np.random.shuffle(calib_files)
    rpn_calib_files = [x for x in calib_files if 'rpn' in x]
    pfe_calib_files = [x for x in calib_files if 'pfe' in x]
class EntropyCalibrator(trt.IInt8EntropyCalibrator2):
    def __init__(self, datas, cache_file="calib_cache.bin", batch_size=1,shape = (1,32000,20,10)):
        # Whenever you specify a custom constructor for a TensorRT class,
        # you MUST call the constructor of the parent explicitly.
        trt.IInt8EntropyCalibrator2.__init__(self)
        self.shape = shape
        self.cache_file = cache_file
        # Every time get_batch is called, the next batch of size batch_size will be copied to the device and returned.
        assert isinstance(datas, list) and len(datas), "datas should be a type of `list`and should not be empty. "
        # if isinstance(datas[0], str) :   self.read_cache = False
        # elif isinstance(datas[0], np.ndarray) : self.read_cache = True
        # else: raise TypeError("Can't recognize calibration data types.")
        self.datas = datas
        self.data = self.read_data(0)

        self.batch_size = batch_size
        self.current_index = 0
        # Allocate enough memory for a whole batch.
        # Allocate enough memory for a whole batch.
        # print("alloc size " , self.data[0].nbytes * self.batch_size)
        self.device_input = cuda.mem_alloc(self.data.nbytes * self.batch_size)
    def read_data(self,idx):
        # if self.read_cache:
        #     data = self.datas[idx].astype(np.float32)
        # else:
            # data = np.fromfile(self.datas[idx],dtype = np.float32)
        data = np.fromfile(self.datas[idx],dtype = np.float32)
        #data = np.ascontiguousarray(data.reshape(*self.shape[1:])).ravel()
        return data
        
    def get_batch_size(self):
        return self.batch_size
    # TensorRT passes along the names of the engine bindings to the get_batch function.
    # You don't necessarily have to use them, but they can be useful to understand the order of
    # the inputs. The bindings list is expected to have the same ordering as 'names'.
    def get_batch(self, names):
        if self.current_index + self.batch_size > len(self.datas):
            return None
        current_batch = int(self.current_index / self.batch_size)
        if current_batch % 1 == 0:
            print("Calibrating batch {:}, {}".format(current_batch,  self.datas[self.current_index] ))
        batch = []
        for i in range(self.batch_size):
            sample = self.read_data(self.current_index + i)
            batch.append(sample)
        batch = np.stack(batch,axis = 0)
        batch = np.ascontiguousarray(batch.reshape(*self.shape)).ravel()
        #batch = self.read_data(self.current_index )
        cuda.memcpy_htod(self.device_input, batch)
        self.current_index += self.batch_size
        return [self.device_input]
    def read_calibration_cache(self):
        # If there is a cache, use it instead of calibrating again. Otherwise, implicitly return None.
#         if os.path.exists(self.cache_file):
#             with open(self.cache_file, "rb") as f:
#                 return f.read()
        pass
    def write_calibration_cache(self, cache):
        with open(self.cache_file, "wb") as f:
            f.write(cache)
# Out:
# 1027 calib files for each model.

# %% [markdown]
# ### For pfe engine creation

# %%
args.quant = False
args.pfe_engine_path = "pfe_fp.engine"

TRT_LOGGER = trt.Logger(trt.Logger.WARNING)
with trt.Builder(TRT_LOGGER) as builder, \
builder.create_network(1 << int(trt.NetworkDefinitionCreationFlag.EXPLICIT_BATCH)) as network, \
trt.OnnxParser(network,TRT_LOGGER) as parser, \
builder.create_builder_config() as config:
    config.max_workspace_size = 1 << 30
    builder.max_batch_size = 1

    if args.quant:
        config.set_flag(trt.BuilderFlag.INT8)

        pfe_calib = EntropyCalibrator(pfe_calib_files,  cache_file="pfe_calib_cache.bin", shape = (args.calib_batch_size, cfg.max_pillars, cfg.max_points_in_voxel, cfg.feature_num) )
        config.int8_calibrator = pfe_calib
    else : 
        config.set_flag(trt.BuilderFlag.FP16)

    parsed = parser.parse_from_file(args.pfe_onnx_path)
    if parsed:
        print("building pfe trt engine . . .")
        serialized_engine = builder.build_serialized_network(network,config)
        with open(args.pfe_engine_path, 'wb') as f:
            f.write(serialized_engine)

        print("deserialize the engine . . . ")
        runtime = trt.Runtime(TRT_LOGGER)
        engine = runtime.deserialize_cuda_engine(serialized_engine)
        context = engine.create_execution_context()
        print("context_pfe", context)

    else:
        print("Parsing Failed ! ")
        for i in range(parser.num_errors):
            print(parser.get_error(i))
# Out:
# building pfe trt engine . . .
# deserialize the engine . . .
# context_pfe <tensorrt.tensorrt.IExecutionContext object at 0x7fd1c3237ab0>

# %%
TRT_LOGGER = trt.Logger(trt.Logger.WARNING)
with trt.Builder(TRT_LOGGER) as builder, \
builder.create_network(1 << int(trt.NetworkDefinitionCreationFlag.EXPLICIT_BATCH)) as network, \
trt.OnnxParser(network,TRT_LOGGER) as parser, \
builder.create_builder_config() as config:
    config.max_workspace_size = 1 << 30
    builder.max_batch_size = 1
    if args.quant:
        config.set_flag(trt.BuilderFlag.INT8)

        rpn_calib = EntropyCalibrator(rpn_calib_files,  cache_file="rpn_calib_cache.bin", shape = (args.calib_batch_size, cfg.pfe_output_dim, cfg.bev_h, cfg.bev_w) )
        config.int8_calibrator = rpn_calib
    else : 
        config.set_flag(trt.BuilderFlag.FP16)
        
    parsed = parser.parse_from_file(args.rpn_onnx_path)
    if parsed:
        print("building rpn trt engine . . .")
        serialized_engine = builder.build_serialized_network(network,config)
        with open(args.rpn_engine_path, 'wb') as f:
            f.write(serialized_engine)

        print("deserialize the engine . . . ")
        runtime = trt.Runtime(TRT_LOGGER)
        rpn_engine = runtime.deserialize_cuda_engine(serialized_engine)
        rpn_context = rpn_engine.create_execution_context()
        print("context_rpn", rpn_context)

    else:
        print("Parsing Failed ! ")
        for i in range(parser.num_errors):
            print(parser.get_error(i))
# Out:
# building rpn trt engine . . .
# Calibrating batch 0, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_29_frame_172_rpn_input.bin
# Calibrating batch 1, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_186_frame_91_rpn_input.bin
# Calibrating batch 2, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_155_frame_152_rpn_input.bin
# Calibrating batch 3, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_147_frame_4_rpn_input.bin
# Calibrating batch 4, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_24_frame_95_rpn_input.bin
# Calibrating batch 5, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_130_frame_119_rpn_input.bin
# Calibrating batch 6, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_66_frame_6_rpn_input.bin
# Calibrating batch 7, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_98_frame_54_rpn_input.bin
# Calibrating batch 8, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_123_frame_34_rpn_input.bin
# Calibrating batch 9, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_110_frame_19_rpn_input.bin
# Calibrating batch 10, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_129_frame_48_rpn_input.bin
# Calibrating batch 11, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_187_frame_104_rpn_input.bin
# Calibrating batch 12, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_57_frame_189_rpn_input.bin
# Calibrating batch 13, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_54_frame_136_rpn_input.bin
# Calibrating batch 14, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_181_frame_173_rpn_input.bin
# Calibrating batch 15, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_168_frame_85_rpn_input.bin
# Calibrating batch 16, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_153_frame_195_rpn_input.bin
# Calibrating batch 17, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_34_frame_96_rpn_input.bin
# Calibrating batch 18, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_124_frame_71_rpn_input.bin
# Calibrating batch 19, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_31_frame_59_rpn_input.bin
# Calibrating batch 20, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_71_frame_63_rpn_input.bin
# Calibrating batch 21, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_33_frame_51_rpn_input.bin
# Calibrating batch 22, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_169_frame_4_rpn_input.bin
# Calibrating batch 23, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_11_frame_105_rpn_input.bin
# Calibrating batch 24, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_108_frame_141_rpn_input.bin
# Calibrating batch 25, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_45_frame_7_rpn_input.bin
# Calibrating batch 26, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_133_frame_86_rpn_input.bin
# Calibrating batch 27, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_192_frame_94_rpn_input.bin
# Calibrating batch 28, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_16_frame_148_rpn_input.bin
# Calibrating batch 29, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_162_frame_188_rpn_input.bin
# Calibrating batch 30, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_81_frame_60_rpn_input.bin
# Calibrating batch 31, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_32_frame_84_rpn_input.bin
# Calibrating batch 32, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_41_frame_93_rpn_input.bin
# Calibrating batch 33, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_115_frame_92_rpn_input.bin
# Calibrating batch 34, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_35_frame_3_rpn_input.bin
# Calibrating batch 35, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_117_frame_187_rpn_input.bin
# Calibrating batch 36, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_127_frame_177_rpn_input.bin
# Calibrating batch 37, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_139_frame_134_rpn_input.bin
# Calibrating batch 38, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_156_frame_144_rpn_input.bin
# Calibrating batch 39, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_92_frame_68_rpn_input.bin
# Calibrating batch 40, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_128_frame_91_rpn_input.bin
# Calibrating batch 41, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_149_frame_118_rpn_input.bin
# Calibrating batch 42, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_153_frame_36_rpn_input.bin
# Calibrating batch 43, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_125_frame_180_rpn_input.bin
# Calibrating batch 44, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_157_frame_22_rpn_input.bin
# Calibrating batch 45, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_27_frame_67_rpn_input.bin
# Calibrating batch 46, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_58_frame_139_rpn_input.bin
# Calibrating batch 47, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_94_frame_68_rpn_input.bin
# Calibrating batch 48, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_133_frame_23_rpn_input.bin
# Calibrating batch 49, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_198_frame_51_rpn_input.bin
# Calibrating batch 50, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_106_frame_135_rpn_input.bin
# Calibrating batch 51, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_105_frame_9_rpn_input.bin
# Calibrating batch 52, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_79_frame_120_rpn_input.bin
# Calibrating batch 53, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_162_frame_114_rpn_input.bin
# Calibrating batch 54, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_19_frame_95_rpn_input.bin
# Calibrating batch 55, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_107_frame_6_rpn_input.bin
# Calibrating batch 56, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_85_frame_0_rpn_input.bin
# Calibrating batch 57, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_122_frame_150_rpn_input.bin
# Calibrating batch 58, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_115_frame_164_rpn_input.bin
# Calibrating batch 59, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_152_frame_192_rpn_input.bin
# Calibrating batch 60, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_55_frame_51_rpn_input.bin
# Calibrating batch 61, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_134_frame_121_rpn_input.bin
# Calibrating batch 62, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_32_frame_139_rpn_input.bin
# Calibrating batch 63, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_111_frame_130_rpn_input.bin
# Calibrating batch 64, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_120_frame_95_rpn_input.bin
# Calibrating batch 65, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_177_frame_82_rpn_input.bin
# Calibrating batch 66, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_196_frame_36_rpn_input.bin
# Calibrating batch 67, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_123_frame_131_rpn_input.bin
# Calibrating batch 68, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_189_frame_187_rpn_input.bin
# Calibrating batch 69, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_175_frame_107_rpn_input.bin
# Calibrating batch 70, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_41_frame_138_rpn_input.bin
# Calibrating batch 71, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_122_frame_19_rpn_input.bin
# Calibrating batch 72, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_16_frame_161_rpn_input.bin
# Calibrating batch 73, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_26_frame_97_rpn_input.bin
# Calibrating batch 74, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_58_frame_86_rpn_input.bin
# Calibrating batch 75, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_102_frame_95_rpn_input.bin
# Calibrating batch 76, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_26_frame_51_rpn_input.bin
# Calibrating batch 77, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_166_frame_176_rpn_input.bin
# Calibrating batch 78, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_77_frame_143_rpn_input.bin
# Calibrating batch 79, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_136_frame_65_rpn_input.bin
# Calibrating batch 80, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_68_frame_39_rpn_input.bin
# Calibrating batch 81, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_54_frame_72_rpn_input.bin
# Calibrating batch 82, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_198_frame_178_rpn_input.bin
# Calibrating batch 83, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_39_frame_79_rpn_input.bin
# Calibrating batch 84, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_96_frame_171_rpn_input.bin
# Calibrating batch 85, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_12_frame_147_rpn_input.bin
# Calibrating batch 86, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_45_frame_150_rpn_input.bin
# Calibrating batch 87, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_46_frame_175_rpn_input.bin
# Calibrating batch 88, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_165_frame_92_rpn_input.bin
# Calibrating batch 89, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_159_frame_165_rpn_input.bin
# Calibrating batch 90, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_94_frame_36_rpn_input.bin
# Calibrating batch 91, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_83_frame_22_rpn_input.bin
# Calibrating batch 92, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_74_frame_0_rpn_input.bin
# Calibrating batch 93, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_56_frame_165_rpn_input.bin
# Calibrating batch 94, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_142_frame_16_rpn_input.bin
# Calibrating batch 95, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_36_frame_150_rpn_input.bin
# Calibrating batch 96, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_90_frame_11_rpn_input.bin
# Calibrating batch 97, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_182_frame_36_rpn_input.bin
# Calibrating batch 98, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_139_frame_74_rpn_input.bin
# Calibrating batch 99, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_172_frame_18_rpn_input.bin
# Calibrating batch 100, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_59_frame_160_rpn_input.bin
# Calibrating batch 101, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_114_frame_129_rpn_input.bin
# Calibrating batch 102, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_79_frame_77_rpn_input.bin
# Calibrating batch 103, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_137_frame_184_rpn_input.bin
# Calibrating batch 104, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_43_frame_112_rpn_input.bin
# Calibrating batch 105, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_12_frame_146_rpn_input.bin
# Calibrating batch 106, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_118_frame_105_rpn_input.bin
# Calibrating batch 107, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_146_frame_107_rpn_input.bin
# Calibrating batch 108, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_55_frame_170_rpn_input.bin
# Calibrating batch 109, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_172_frame_118_rpn_input.bin
# Calibrating batch 110, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_96_frame_5_rpn_input.bin
# Calibrating batch 111, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_186_frame_92_rpn_input.bin
# Calibrating batch 112, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_25_frame_139_rpn_input.bin
# Calibrating batch 113, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_99_frame_86_rpn_input.bin
# Calibrating batch 114, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_166_frame_80_rpn_input.bin
# Calibrating batch 115, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_99_frame_194_rpn_input.bin
# Calibrating batch 116, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_121_frame_147_rpn_input.bin
# Calibrating batch 117, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_36_frame_179_rpn_input.bin
# Calibrating batch 118, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_30_frame_148_rpn_input.bin
# Calibrating batch 119, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_33_frame_30_rpn_input.bin
# Calibrating batch 120, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_72_frame_157_rpn_input.bin
# Calibrating batch 121, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_100_frame_83_rpn_input.bin
# Calibrating batch 122, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_26_frame_87_rpn_input.bin
# Calibrating batch 123, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_113_frame_93_rpn_input.bin
# Calibrating batch 124, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_2_frame_153_rpn_input.bin
# Calibrating batch 125, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_103_frame_146_rpn_input.bin
# Calibrating batch 126, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_191_frame_161_rpn_input.bin
# Calibrating batch 127, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_99_frame_156_rpn_input.bin
# Calibrating batch 128, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_130_frame_184_rpn_input.bin
# Calibrating batch 129, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_50_frame_72_rpn_input.bin
# Calibrating batch 130, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_107_frame_10_rpn_input.bin
# Calibrating batch 131, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_28_frame_85_rpn_input.bin
# Calibrating batch 132, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_49_frame_141_rpn_input.bin
# Calibrating batch 133, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_52_frame_7_rpn_input.bin
# Calibrating batch 134, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_193_frame_118_rpn_input.bin
# Calibrating batch 135, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_92_frame_174_rpn_input.bin
# Calibrating batch 136, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_117_frame_142_rpn_input.bin
# Calibrating batch 137, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_27_frame_24_rpn_input.bin
# Calibrating batch 138, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_46_frame_76_rpn_input.bin
# Calibrating batch 139, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_132_frame_99_rpn_input.bin
# Calibrating batch 140, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_33_frame_132_rpn_input.bin
# Calibrating batch 141, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_71_frame_36_rpn_input.bin
# Calibrating batch 142, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_191_frame_46_rpn_input.bin
# Calibrating batch 143, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_78_frame_167_rpn_input.bin
# Calibrating batch 144, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_196_frame_134_rpn_input.bin
# Calibrating batch 145, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_39_frame_190_rpn_input.bin
# Calibrating batch 146, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_186_frame_142_rpn_input.bin
# Calibrating batch 147, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_4_frame_145_rpn_input.bin
# Calibrating batch 148, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_51_frame_132_rpn_input.bin
# Calibrating batch 149, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_74_frame_159_rpn_input.bin
# Calibrating batch 150, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_109_frame_22_rpn_input.bin
# Calibrating batch 151, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_196_frame_24_rpn_input.bin
# Calibrating batch 152, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_101_frame_95_rpn_input.bin
# Calibrating batch 153, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_65_frame_75_rpn_input.bin
# Calibrating batch 154, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_111_frame_99_rpn_input.bin
# Calibrating batch 155, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_189_frame_44_rpn_input.bin
# Calibrating batch 156, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_169_frame_49_rpn_input.bin
# Calibrating batch 157, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_115_frame_123_rpn_input.bin
# Calibrating batch 158, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_34_frame_51_rpn_input.bin
# Calibrating batch 159, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_164_frame_67_rpn_input.bin
# Calibrating batch 160, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_122_frame_79_rpn_input.bin
# Calibrating batch 161, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_103_frame_81_rpn_input.bin
# Calibrating batch 162, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_132_frame_8_rpn_input.bin
# Calibrating batch 163, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_193_frame_181_rpn_input.bin
# Calibrating batch 164, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_66_frame_142_rpn_input.bin
# Calibrating batch 165, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_47_frame_136_rpn_input.bin
# Calibrating batch 166, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_179_frame_6_rpn_input.bin
# Calibrating batch 167, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_29_frame_195_rpn_input.bin
# Calibrating batch 168, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_104_frame_150_rpn_input.bin
# Calibrating batch 169, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_135_frame_22_rpn_input.bin
# Calibrating batch 170, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_73_frame_145_rpn_input.bin
# Calibrating batch 171, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_2_frame_54_rpn_input.bin
# Calibrating batch 172, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_135_frame_11_rpn_input.bin
# Calibrating batch 173, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_73_frame_163_rpn_input.bin
# Calibrating batch 174, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_38_frame_103_rpn_input.bin
# Calibrating batch 175, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_43_frame_141_rpn_input.bin
# Calibrating batch 176, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_191_frame_123_rpn_input.bin
# Calibrating batch 177, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_90_frame_75_rpn_input.bin
# Calibrating batch 178, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_76_frame_198_rpn_input.bin
# Calibrating batch 179, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_191_frame_178_rpn_input.bin
# Calibrating batch 180, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_156_frame_125_rpn_input.bin
# Calibrating batch 181, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_200_frame_9_rpn_input.bin
# Calibrating batch 182, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_141_frame_186_rpn_input.bin
# Calibrating batch 183, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_3_frame_38_rpn_input.bin
# Calibrating batch 184, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_136_frame_46_rpn_input.bin
# Calibrating batch 185, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_49_frame_13_rpn_input.bin
# Calibrating batch 186, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_194_frame_138_rpn_input.bin
# Calibrating batch 187, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_96_frame_195_rpn_input.bin
# Calibrating batch 188, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_91_frame_60_rpn_input.bin
# Calibrating batch 189, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_118_frame_115_rpn_input.bin
# Calibrating batch 190, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_141_frame_2_rpn_input.bin
# Calibrating batch 191, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_116_frame_117_rpn_input.bin
# Calibrating batch 192, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_41_frame_41_rpn_input.bin
# Calibrating batch 193, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_164_frame_128_rpn_input.bin
# Calibrating batch 194, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_168_frame_8_rpn_input.bin
# Calibrating batch 195, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_175_frame_0_rpn_input.bin
# Calibrating batch 196, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_114_frame_5_rpn_input.bin
# Calibrating batch 197, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_100_frame_127_rpn_input.bin
# Calibrating batch 198, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_11_frame_153_rpn_input.bin
# Calibrating batch 199, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_154_frame_156_rpn_input.bin
# Calibrating batch 200, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_187_frame_167_rpn_input.bin
# Calibrating batch 201, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_114_frame_143_rpn_input.bin
# Calibrating batch 202, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_60_frame_177_rpn_input.bin
# Calibrating batch 203, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_33_frame_99_rpn_input.bin
# Calibrating batch 204, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_182_frame_103_rpn_input.bin
# Calibrating batch 205, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_156_frame_8_rpn_input.bin
# Calibrating batch 206, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_184_frame_90_rpn_input.bin
# Calibrating batch 207, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_188_frame_28_rpn_input.bin
# Calibrating batch 208, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_16_frame_89_rpn_input.bin
# Calibrating batch 209, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_46_frame_150_rpn_input.bin
# Calibrating batch 210, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_37_frame_33_rpn_input.bin
# Calibrating batch 211, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_13_frame_58_rpn_input.bin
# Calibrating batch 212, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_9_frame_49_rpn_input.bin
# Calibrating batch 213, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_38_frame_173_rpn_input.bin
# Calibrating batch 214, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_141_frame_114_rpn_input.bin
# Calibrating batch 215, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_26_frame_83_rpn_input.bin
# Calibrating batch 216, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_135_frame_143_rpn_input.bin
# Calibrating batch 217, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_25_frame_64_rpn_input.bin
# Calibrating batch 218, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_33_frame_27_rpn_input.bin
# Calibrating batch 219, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_4_frame_22_rpn_input.bin
# Calibrating batch 220, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_23_frame_38_rpn_input.bin
# Calibrating batch 221, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_3_frame_188_rpn_input.bin
# Calibrating batch 222, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_4_frame_183_rpn_input.bin
# Calibrating batch 223, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_142_frame_138_rpn_input.bin
# Calibrating batch 224, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_66_frame_113_rpn_input.bin
# Calibrating batch 225, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_32_frame_56_rpn_input.bin
# Calibrating batch 226, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_189_frame_45_rpn_input.bin
# Calibrating batch 227, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_124_frame_15_rpn_input.bin
# Calibrating batch 228, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_23_frame_83_rpn_input.bin
# Calibrating batch 229, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_186_frame_114_rpn_input.bin
# Calibrating batch 230, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_44_frame_69_rpn_input.bin
# Calibrating batch 231, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_3_frame_120_rpn_input.bin
# Calibrating batch 232, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_93_frame_23_rpn_input.bin
# Calibrating batch 233, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_199_frame_103_rpn_input.bin
# Calibrating batch 234, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_135_frame_106_rpn_input.bin
# Calibrating batch 235, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_17_frame_34_rpn_input.bin
# Calibrating batch 236, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_182_frame_177_rpn_input.bin
# Calibrating batch 237, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_193_frame_28_rpn_input.bin
# Calibrating batch 238, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_119_frame_42_rpn_input.bin
# Calibrating batch 239, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_172_frame_80_rpn_input.bin
# Calibrating batch 240, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_87_frame_79_rpn_input.bin
# Calibrating batch 241, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_79_frame_47_rpn_input.bin
# Calibrating batch 242, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_44_frame_9_rpn_input.bin
# Calibrating batch 243, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_29_frame_112_rpn_input.bin
# Calibrating batch 244, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_120_frame_79_rpn_input.bin
# Calibrating batch 245, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_141_frame_89_rpn_input.bin
# Calibrating batch 246, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_89_frame_3_rpn_input.bin
# Calibrating batch 247, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_159_frame_171_rpn_input.bin
# Calibrating batch 248, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_188_frame_124_rpn_input.bin
# Calibrating batch 249, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_105_frame_54_rpn_input.bin
# Calibrating batch 250, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_29_frame_99_rpn_input.bin
# Calibrating batch 251, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_41_frame_4_rpn_input.bin
# Calibrating batch 252, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_106_frame_154_rpn_input.bin
# Calibrating batch 253, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_195_frame_34_rpn_input.bin
# Calibrating batch 254, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_181_frame_165_rpn_input.bin
# Calibrating batch 255, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_81_frame_37_rpn_input.bin
# Calibrating batch 256, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_94_frame_78_rpn_input.bin
# Calibrating batch 257, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_122_frame_142_rpn_input.bin
# Calibrating batch 258, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_182_frame_2_rpn_input.bin
# Calibrating batch 259, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_95_frame_142_rpn_input.bin
# Calibrating batch 260, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_200_frame_25_rpn_input.bin
# Calibrating batch 261, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_178_frame_52_rpn_input.bin
# Calibrating batch 262, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_54_frame_133_rpn_input.bin
# Calibrating batch 263, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_3_frame_133_rpn_input.bin
# Calibrating batch 264, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_46_frame_80_rpn_input.bin
# Calibrating batch 265, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_11_frame_14_rpn_input.bin
# Calibrating batch 266, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_81_frame_62_rpn_input.bin
# Calibrating batch 267, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_123_frame_128_rpn_input.bin
# Calibrating batch 268, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_191_frame_115_rpn_input.bin
# Calibrating batch 269, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_171_frame_72_rpn_input.bin
# Calibrating batch 270, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_47_frame_97_rpn_input.bin
# Calibrating batch 271, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_48_frame_180_rpn_input.bin
# Calibrating batch 272, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_179_frame_85_rpn_input.bin
# Calibrating batch 273, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_20_frame_103_rpn_input.bin
# Calibrating batch 274, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_35_frame_124_rpn_input.bin
# Calibrating batch 275, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_1_frame_189_rpn_input.bin
# Calibrating batch 276, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_156_frame_100_rpn_input.bin
# Calibrating batch 277, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_180_frame_159_rpn_input.bin
# Calibrating batch 278, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_152_frame_63_rpn_input.bin
# Calibrating batch 279, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_50_frame_16_rpn_input.bin
# Calibrating batch 280, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_86_frame_74_rpn_input.bin
# Calibrating batch 281, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_101_frame_171_rpn_input.bin
# Calibrating batch 282, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_80_frame_35_rpn_input.bin
# Calibrating batch 283, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_53_frame_196_rpn_input.bin
# Calibrating batch 284, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_157_frame_171_rpn_input.bin
# Calibrating batch 285, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_75_frame_86_rpn_input.bin
# Calibrating batch 286, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_3_frame_91_rpn_input.bin
# Calibrating batch 287, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_120_frame_191_rpn_input.bin
# Calibrating batch 288, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_104_frame_56_rpn_input.bin
# Calibrating batch 289, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_39_frame_13_rpn_input.bin
# Calibrating batch 290, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_180_frame_47_rpn_input.bin
# Calibrating batch 291, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_2_frame_149_rpn_input.bin
# Calibrating batch 292, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_147_frame_12_rpn_input.bin
# Calibrating batch 293, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_161_frame_95_rpn_input.bin
# Calibrating batch 294, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_171_frame_46_rpn_input.bin
# Calibrating batch 295, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_160_frame_117_rpn_input.bin
# Calibrating batch 296, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_48_frame_16_rpn_input.bin
# Calibrating batch 297, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_39_frame_165_rpn_input.bin
# Calibrating batch 298, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_121_frame_90_rpn_input.bin
# Calibrating batch 299, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_12_frame_53_rpn_input.bin
# Calibrating batch 300, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_27_frame_52_rpn_input.bin
# Calibrating batch 301, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_84_frame_135_rpn_input.bin
# Calibrating batch 302, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_108_frame_188_rpn_input.bin
# Calibrating batch 303, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_141_frame_174_rpn_input.bin
# Calibrating batch 304, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_35_frame_128_rpn_input.bin
# Calibrating batch 305, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_37_frame_153_rpn_input.bin
# Calibrating batch 306, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_51_frame_166_rpn_input.bin
# Calibrating batch 307, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_51_frame_179_rpn_input.bin
# Calibrating batch 308, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_2_frame_113_rpn_input.bin
# Calibrating batch 309, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_177_frame_97_rpn_input.bin
# Calibrating batch 310, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_167_frame_32_rpn_input.bin
# Calibrating batch 311, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_2_frame_127_rpn_input.bin
# Calibrating batch 312, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_90_frame_40_rpn_input.bin
# Calibrating batch 313, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_5_frame_24_rpn_input.bin
# Calibrating batch 314, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_181_frame_146_rpn_input.bin
# Calibrating batch 315, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_197_frame_189_rpn_input.bin
# Calibrating batch 316, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_38_frame_71_rpn_input.bin
# Calibrating batch 317, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_169_frame_128_rpn_input.bin
# Calibrating batch 318, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_78_frame_146_rpn_input.bin
# Calibrating batch 319, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_101_frame_135_rpn_input.bin
# Calibrating batch 320, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_109_frame_98_rpn_input.bin
# Calibrating batch 321, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_149_frame_128_rpn_input.bin
# Calibrating batch 322, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_177_frame_28_rpn_input.bin
# Calibrating batch 323, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_15_frame_81_rpn_input.bin
# Calibrating batch 324, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_133_frame_90_rpn_input.bin
# Calibrating batch 325, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_13_frame_47_rpn_input.bin
# Calibrating batch 326, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_30_frame_58_rpn_input.bin
# Calibrating batch 327, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_153_frame_107_rpn_input.bin
# Calibrating batch 328, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_197_frame_4_rpn_input.bin
# Calibrating batch 329, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_43_frame_75_rpn_input.bin
# Calibrating batch 330, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_200_frame_192_rpn_input.bin
# Calibrating batch 331, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_182_frame_5_rpn_input.bin
# Calibrating batch 332, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_96_frame_57_rpn_input.bin
# Calibrating batch 333, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_112_frame_10_rpn_input.bin
# Calibrating batch 334, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_85_frame_6_rpn_input.bin
# Calibrating batch 335, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_199_frame_110_rpn_input.bin
# Calibrating batch 336, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_84_frame_183_rpn_input.bin
# Calibrating batch 337, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_176_frame_115_rpn_input.bin
# Calibrating batch 338, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_175_frame_178_rpn_input.bin
# Calibrating batch 339, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_171_frame_129_rpn_input.bin
# Calibrating batch 340, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_131_frame_53_rpn_input.bin
# Calibrating batch 341, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_56_frame_180_rpn_input.bin
# Calibrating batch 342, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_12_frame_85_rpn_input.bin
# Calibrating batch 343, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_120_frame_20_rpn_input.bin
# Calibrating batch 344, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_115_frame_17_rpn_input.bin
# Calibrating batch 345, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_173_frame_159_rpn_input.bin
# Calibrating batch 346, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_168_frame_150_rpn_input.bin
# Calibrating batch 347, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_115_frame_118_rpn_input.bin
# Calibrating batch 348, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_168_frame_106_rpn_input.bin
# Calibrating batch 349, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_40_frame_65_rpn_input.bin
# Calibrating batch 350, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_184_frame_106_rpn_input.bin
# Calibrating batch 351, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_62_frame_58_rpn_input.bin
# Calibrating batch 352, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_200_frame_52_rpn_input.bin
# Calibrating batch 353, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_198_frame_156_rpn_input.bin
# Calibrating batch 354, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_24_frame_86_rpn_input.bin
# Calibrating batch 355, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_180_frame_39_rpn_input.bin
# Calibrating batch 356, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_196_frame_80_rpn_input.bin
# Calibrating batch 357, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_107_frame_142_rpn_input.bin
# Calibrating batch 358, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_21_frame_186_rpn_input.bin
# Calibrating batch 359, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_93_frame_195_rpn_input.bin
# Calibrating batch 360, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_28_frame_59_rpn_input.bin
# Calibrating batch 361, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_62_frame_55_rpn_input.bin
# Calibrating batch 362, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_112_frame_137_rpn_input.bin
# Calibrating batch 363, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_138_frame_122_rpn_input.bin
# Calibrating batch 364, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_56_frame_47_rpn_input.bin
# Calibrating batch 365, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_72_frame_71_rpn_input.bin
# Calibrating batch 366, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_43_frame_93_rpn_input.bin
# Calibrating batch 367, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_31_frame_20_rpn_input.bin
# Calibrating batch 368, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_124_frame_90_rpn_input.bin
# Calibrating batch 369, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_60_frame_110_rpn_input.bin
# Calibrating batch 370, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_166_frame_55_rpn_input.bin
# Calibrating batch 371, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_136_frame_39_rpn_input.bin
# Calibrating batch 372, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_32_frame_179_rpn_input.bin
# Calibrating batch 373, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_99_frame_133_rpn_input.bin
# Calibrating batch 374, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_131_frame_117_rpn_input.bin
# Calibrating batch 375, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_89_frame_0_rpn_input.bin
# Calibrating batch 376, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_100_frame_133_rpn_input.bin
# Calibrating batch 377, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_105_frame_28_rpn_input.bin
# Calibrating batch 378, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_102_frame_75_rpn_input.bin
# Calibrating batch 379, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_11_frame_146_rpn_input.bin
# Calibrating batch 380, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_149_frame_134_rpn_input.bin
# Calibrating batch 381, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_74_frame_101_rpn_input.bin
# Calibrating batch 382, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_81_frame_157_rpn_input.bin
# Calibrating batch 383, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_19_frame_125_rpn_input.bin
# Calibrating batch 384, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_165_frame_90_rpn_input.bin
# Calibrating batch 385, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_111_frame_89_rpn_input.bin
# Calibrating batch 386, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_176_frame_163_rpn_input.bin
# Calibrating batch 387, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_106_frame_43_rpn_input.bin
# Calibrating batch 388, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_164_frame_142_rpn_input.bin
# Calibrating batch 389, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_2_frame_46_rpn_input.bin
# Calibrating batch 390, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_119_frame_61_rpn_input.bin
# Calibrating batch 391, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_15_frame_179_rpn_input.bin
# Calibrating batch 392, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_196_frame_161_rpn_input.bin
# Calibrating batch 393, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_133_frame_64_rpn_input.bin
# Calibrating batch 394, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_62_frame_47_rpn_input.bin
# Calibrating batch 395, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_91_frame_194_rpn_input.bin
# Calibrating batch 396, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_130_frame_95_rpn_input.bin
# Calibrating batch 397, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_98_frame_110_rpn_input.bin
# Calibrating batch 398, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_154_frame_149_rpn_input.bin
# Calibrating batch 399, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_41_frame_146_rpn_input.bin
# Calibrating batch 400, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_103_frame_23_rpn_input.bin
# Calibrating batch 401, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_198_frame_53_rpn_input.bin
# Calibrating batch 402, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_9_frame_82_rpn_input.bin
# Calibrating batch 403, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_167_frame_14_rpn_input.bin
# Calibrating batch 404, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_137_frame_115_rpn_input.bin
# Calibrating batch 405, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_17_frame_36_rpn_input.bin
# Calibrating batch 406, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_26_frame_32_rpn_input.bin
# Calibrating batch 407, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_69_frame_184_rpn_input.bin
# Calibrating batch 408, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_16_frame_47_rpn_input.bin
# Calibrating batch 409, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_89_frame_193_rpn_input.bin
# Calibrating batch 410, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_31_frame_139_rpn_input.bin
# Calibrating batch 411, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_14_frame_128_rpn_input.bin
# Calibrating batch 412, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_50_frame_192_rpn_input.bin
# Calibrating batch 413, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_143_frame_46_rpn_input.bin
# Calibrating batch 414, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_61_frame_112_rpn_input.bin
# Calibrating batch 415, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_113_frame_151_rpn_input.bin
# Calibrating batch 416, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_87_frame_73_rpn_input.bin
# Calibrating batch 417, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_177_frame_86_rpn_input.bin
# Calibrating batch 418, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_159_frame_5_rpn_input.bin
# Calibrating batch 419, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_9_frame_163_rpn_input.bin
# Calibrating batch 420, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_51_frame_139_rpn_input.bin
# Calibrating batch 421, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_69_frame_78_rpn_input.bin
# Calibrating batch 422, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_7_frame_196_rpn_input.bin
# Calibrating batch 423, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_76_frame_175_rpn_input.bin
# Calibrating batch 424, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_38_frame_184_rpn_input.bin
# Calibrating batch 425, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_91_frame_172_rpn_input.bin
# Calibrating batch 426, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_74_frame_61_rpn_input.bin
# Calibrating batch 427, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_111_frame_114_rpn_input.bin
# Calibrating batch 428, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_169_frame_55_rpn_input.bin
# Calibrating batch 429, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_4_frame_33_rpn_input.bin
# Calibrating batch 430, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_124_frame_8_rpn_input.bin
# Calibrating batch 431, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_111_frame_65_rpn_input.bin
# Calibrating batch 432, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_168_frame_163_rpn_input.bin
# Calibrating batch 433, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_61_frame_75_rpn_input.bin
# Calibrating batch 434, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_132_frame_180_rpn_input.bin
# Calibrating batch 435, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_43_frame_98_rpn_input.bin
# Calibrating batch 436, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_51_frame_67_rpn_input.bin
# Calibrating batch 437, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_163_frame_143_rpn_input.bin
# Calibrating batch 438, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_38_frame_39_rpn_input.bin
# Calibrating batch 439, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_91_frame_19_rpn_input.bin
# Calibrating batch 440, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_107_frame_73_rpn_input.bin
# Calibrating batch 441, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_158_frame_61_rpn_input.bin
# Calibrating batch 442, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_173_frame_93_rpn_input.bin
# Calibrating batch 443, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_67_frame_119_rpn_input.bin
# Calibrating batch 444, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_139_frame_115_rpn_input.bin
# Calibrating batch 445, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_98_frame_9_rpn_input.bin
# Calibrating batch 446, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_71_frame_121_rpn_input.bin
# Calibrating batch 447, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_58_frame_103_rpn_input.bin
# Calibrating batch 448, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_132_frame_46_rpn_input.bin
# Calibrating batch 449, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_165_frame_104_rpn_input.bin
# Calibrating batch 450, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_120_frame_171_rpn_input.bin
# Calibrating batch 451, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_147_frame_31_rpn_input.bin
# Calibrating batch 452, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_81_frame_98_rpn_input.bin
# Calibrating batch 453, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_46_frame_107_rpn_input.bin
# Calibrating batch 454, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_64_frame_130_rpn_input.bin
# Calibrating batch 455, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_80_frame_80_rpn_input.bin
# Calibrating batch 456, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_60_frame_120_rpn_input.bin
# Calibrating batch 457, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_168_frame_97_rpn_input.bin
# Calibrating batch 458, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_72_frame_33_rpn_input.bin
# Calibrating batch 459, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_194_frame_32_rpn_input.bin
# Calibrating batch 460, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_85_frame_184_rpn_input.bin
# Calibrating batch 461, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_140_frame_152_rpn_input.bin
# Calibrating batch 462, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_199_frame_47_rpn_input.bin
# Calibrating batch 463, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_136_frame_188_rpn_input.bin
# Calibrating batch 464, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_57_frame_36_rpn_input.bin
# Calibrating batch 465, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_92_frame_118_rpn_input.bin
# Calibrating batch 466, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_181_frame_105_rpn_input.bin
# Calibrating batch 467, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_123_frame_37_rpn_input.bin
# Calibrating batch 468, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_160_frame_150_rpn_input.bin
# Calibrating batch 469, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_112_frame_189_rpn_input.bin
# Calibrating batch 470, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_30_frame_86_rpn_input.bin
# Calibrating batch 471, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_139_frame_33_rpn_input.bin
# Calibrating batch 472, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_170_frame_194_rpn_input.bin
# Calibrating batch 473, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_63_frame_119_rpn_input.bin
# Calibrating batch 474, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_41_frame_14_rpn_input.bin
# Calibrating batch 475, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_103_frame_86_rpn_input.bin
# Calibrating batch 476, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_161_frame_40_rpn_input.bin
# Calibrating batch 477, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_26_frame_30_rpn_input.bin
# Calibrating batch 478, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_35_frame_14_rpn_input.bin
# Calibrating batch 479, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_185_frame_128_rpn_input.bin
# Calibrating batch 480, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_195_frame_110_rpn_input.bin
# ...
# Calibrating batch 871, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_23_frame_160_rpn_input.bin
# Calibrating batch 872, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_108_frame_94_rpn_input.bin
# Calibrating batch 873, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_0_frame_46_rpn_input.bin
# Calibrating batch 874, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_138_frame_127_rpn_input.bin
# Calibrating batch 875, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_30_frame_22_rpn_input.bin
# Calibrating batch 876, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_142_frame_67_rpn_input.bin
# Calibrating batch 877, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_80_frame_48_rpn_input.bin
# Calibrating batch 878, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_47_frame_87_rpn_input.bin
# Calibrating batch 879, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_79_frame_190_rpn_input.bin
# Calibrating batch 880, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_95_frame_14_rpn_input.bin
# Calibrating batch 881, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_163_frame_145_rpn_input.bin
# Calibrating batch 882, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_102_frame_5_rpn_input.bin
# Calibrating batch 883, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_67_frame_18_rpn_input.bin
# Calibrating batch 884, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_180_frame_102_rpn_input.bin
# Calibrating batch 885, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_91_frame_131_rpn_input.bin
# Calibrating batch 886, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_145_frame_138_rpn_input.bin
# Calibrating batch 887, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_187_frame_30_rpn_input.bin
# Calibrating batch 888, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_35_frame_156_rpn_input.bin
# Calibrating batch 889, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_110_frame_103_rpn_input.bin
# Calibrating batch 890, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_178_frame_1_rpn_input.bin
# Calibrating batch 891, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_115_frame_32_rpn_input.bin
# Calibrating batch 892, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_127_frame_30_rpn_input.bin
# Calibrating batch 893, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_120_frame_39_rpn_input.bin
# Calibrating batch 894, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_142_frame_136_rpn_input.bin
# Calibrating batch 895, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_111_frame_61_rpn_input.bin
# Calibrating batch 896, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_162_frame_35_rpn_input.bin
# Calibrating batch 897, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_5_frame_94_rpn_input.bin
# Calibrating batch 898, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_76_frame_64_rpn_input.bin
# Calibrating batch 899, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_44_frame_43_rpn_input.bin
# Calibrating batch 900, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_12_frame_84_rpn_input.bin
# Calibrating batch 901, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_38_frame_24_rpn_input.bin
# Calibrating batch 902, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_61_frame_28_rpn_input.bin
# Calibrating batch 903, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_37_frame_25_rpn_input.bin
# Calibrating batch 904, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_55_frame_144_rpn_input.bin
# Calibrating batch 905, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_70_frame_40_rpn_input.bin
# Calibrating batch 906, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_51_frame_188_rpn_input.bin
# Calibrating batch 907, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_66_frame_154_rpn_input.bin
# Calibrating batch 908, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_194_frame_167_rpn_input.bin
# Calibrating batch 909, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_96_frame_154_rpn_input.bin
# Calibrating batch 910, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_190_frame_108_rpn_input.bin
# Calibrating batch 911, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_162_frame_156_rpn_input.bin
# Calibrating batch 912, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_69_frame_100_rpn_input.bin
# Calibrating batch 913, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_148_frame_160_rpn_input.bin
# Calibrating batch 914, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_138_frame_161_rpn_input.bin
# Calibrating batch 915, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_35_frame_197_rpn_input.bin
# Calibrating batch 916, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_72_frame_128_rpn_input.bin
# Calibrating batch 917, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_50_frame_122_rpn_input.bin
# Calibrating batch 918, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_39_frame_71_rpn_input.bin
# Calibrating batch 919, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_55_frame_122_rpn_input.bin
# Calibrating batch 920, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_110_frame_79_rpn_input.bin
# Calibrating batch 921, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_78_frame_92_rpn_input.bin
# Calibrating batch 922, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_178_frame_57_rpn_input.bin
# Calibrating batch 923, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_33_frame_183_rpn_input.bin
# Calibrating batch 924, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_152_frame_179_rpn_input.bin
# Calibrating batch 925, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_145_frame_10_rpn_input.bin
# Calibrating batch 926, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_80_frame_41_rpn_input.bin
# Calibrating batch 927, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_87_frame_76_rpn_input.bin
# Calibrating batch 928, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_107_frame_49_rpn_input.bin
# Calibrating batch 929, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_152_frame_195_rpn_input.bin
# Calibrating batch 930, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_23_frame_106_rpn_input.bin
# Calibrating batch 931, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_187_frame_122_rpn_input.bin
# Calibrating batch 932, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_186_frame_119_rpn_input.bin
# Calibrating batch 933, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_60_frame_72_rpn_input.bin
# Calibrating batch 934, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_147_frame_145_rpn_input.bin
# Calibrating batch 935, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_23_frame_79_rpn_input.bin
# Calibrating batch 936, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_65_frame_40_rpn_input.bin
# Calibrating batch 937, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_137_frame_125_rpn_input.bin
# Calibrating batch 938, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_175_frame_77_rpn_input.bin
# Calibrating batch 939, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_136_frame_130_rpn_input.bin
# Calibrating batch 940, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_24_frame_192_rpn_input.bin
# Calibrating batch 941, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_79_frame_117_rpn_input.bin
# Calibrating batch 942, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_76_frame_148_rpn_input.bin
# Calibrating batch 943, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_96_frame_29_rpn_input.bin
# Calibrating batch 944, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_116_frame_107_rpn_input.bin
# Calibrating batch 945, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_94_frame_157_rpn_input.bin
# Calibrating batch 946, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_163_frame_178_rpn_input.bin
# Calibrating batch 947, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_102_frame_78_rpn_input.bin
# Calibrating batch 948, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_139_frame_138_rpn_input.bin
# Calibrating batch 949, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_3_frame_58_rpn_input.bin
# Calibrating batch 950, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_98_frame_74_rpn_input.bin
# Calibrating batch 951, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_184_frame_48_rpn_input.bin
# Calibrating batch 952, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_71_frame_80_rpn_input.bin
# Calibrating batch 953, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_91_frame_102_rpn_input.bin
# Calibrating batch 954, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_12_frame_194_rpn_input.bin
# Calibrating batch 955, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_199_frame_114_rpn_input.bin
# Calibrating batch 956, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_17_frame_160_rpn_input.bin
# Calibrating batch 957, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_98_frame_94_rpn_input.bin
# Calibrating batch 958, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_186_frame_189_rpn_input.bin
# Calibrating batch 959, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_47_frame_183_rpn_input.bin
# Calibrating batch 960, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_156_frame_196_rpn_input.bin
# Calibrating batch 961, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_36_frame_23_rpn_input.bin
# Calibrating batch 962, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_34_frame_106_rpn_input.bin
# Calibrating batch 963, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_52_frame_68_rpn_input.bin
# Calibrating batch 964, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_19_frame_146_rpn_input.bin
# Calibrating batch 965, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_100_frame_46_rpn_input.bin
# Calibrating batch 966, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_143_frame_31_rpn_input.bin
# Calibrating batch 967, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_67_frame_13_rpn_input.bin
# Calibrating batch 968, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_106_frame_191_rpn_input.bin
# Calibrating batch 969, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_89_frame_66_rpn_input.bin
# Calibrating batch 970, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_165_frame_10_rpn_input.bin
# Calibrating batch 971, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_108_frame_118_rpn_input.bin
# Calibrating batch 972, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_152_frame_154_rpn_input.bin
# Calibrating batch 973, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_116_frame_43_rpn_input.bin
# Calibrating batch 974, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_42_frame_73_rpn_input.bin
# Calibrating batch 975, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_40_frame_112_rpn_input.bin
# Calibrating batch 976, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_84_frame_112_rpn_input.bin
# Calibrating batch 977, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_73_frame_133_rpn_input.bin
# Calibrating batch 978, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_79_frame_15_rpn_input.bin
# Calibrating batch 979, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_69_frame_186_rpn_input.bin
# Calibrating batch 980, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_63_frame_116_rpn_input.bin
# Calibrating batch 981, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_66_frame_87_rpn_input.bin
# Calibrating batch 982, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_11_frame_24_rpn_input.bin
# Calibrating batch 983, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_56_frame_174_rpn_input.bin
# Calibrating batch 984, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_23_frame_45_rpn_input.bin
# Calibrating batch 985, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_155_frame_186_rpn_input.bin
# Calibrating batch 986, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_154_frame_187_rpn_input.bin
# Calibrating batch 987, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_89_frame_47_rpn_input.bin
# Calibrating batch 988, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_188_frame_9_rpn_input.bin
# Calibrating batch 989, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_10_frame_93_rpn_input.bin
# Calibrating batch 990, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_69_frame_9_rpn_input.bin
# Calibrating batch 991, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_180_frame_99_rpn_input.bin
# Calibrating batch 992, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_137_frame_65_rpn_input.bin
# Calibrating batch 993, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_191_frame_61_rpn_input.bin
# Calibrating batch 994, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_165_frame_189_rpn_input.bin
# Calibrating batch 995, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_111_frame_137_rpn_input.bin
# Calibrating batch 996, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_75_frame_55_rpn_input.bin
# Calibrating batch 997, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_129_frame_180_rpn_input.bin
# Calibrating batch 998, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_139_frame_17_rpn_input.bin
# Calibrating batch 999, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_1_frame_180_rpn_input.bin
# Calibrating batch 1000, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_159_frame_7_rpn_input.bin
# Calibrating batch 1001, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_161_frame_78_rpn_input.bin
# Calibrating batch 1002, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_2_frame_21_rpn_input.bin
# Calibrating batch 1003, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_14_frame_171_rpn_input.bin
# Calibrating batch 1004, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_42_frame_178_rpn_input.bin
# Calibrating batch 1005, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_175_frame_63_rpn_input.bin
# Calibrating batch 1006, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_31_frame_80_rpn_input.bin
# Calibrating batch 1007, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_193_frame_156_rpn_input.bin
# Calibrating batch 1008, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_121_frame_32_rpn_input.bin
# Calibrating batch 1009, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_22_frame_52_rpn_input.bin
# Calibrating batch 1010, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_3_frame_105_rpn_input.bin
# Calibrating batch 1011, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_49_frame_84_rpn_input.bin
# Calibrating batch 1012, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_104_frame_69_rpn_input.bin
# Calibrating batch 1013, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_28_frame_100_rpn_input.bin
# Calibrating batch 1014, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_102_frame_84_rpn_input.bin
# Calibrating batch 1015, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_38_frame_175_rpn_input.bin
# Calibrating batch 1016, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_200_frame_74_rpn_input.bin
# Calibrating batch 1017, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_61_frame_186_rpn_input.bin
# Calibrating batch 1018, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_119_frame_152_rpn_input.bin
# Calibrating batch 1019, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_179_frame_86_rpn_input.bin
# Calibrating batch 1020, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_48_frame_167_rpn_input.bin
# Calibrating batch 1021, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_24_frame_114_rpn_input.bin
# Calibrating batch 1022, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_54_frame_8_rpn_input.bin
# Calibrating batch 1023, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_71_frame_168_rpn_input.bin
# Calibrating batch 1024, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_146_frame_88_rpn_input.bin
# Calibrating batch 1025, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_10_frame_83_rpn_input.bin
# Calibrating batch 1026, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_32_frame_100_rpn_input.bin
# Calibrating batch 1027, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_199_frame_136_rpn_input.bin
# Calibrating batch 1028, /mnt/data/waymo_opensets/val/tmp/calibrations/seq_116_frame_123_rpn_input.bin
# deserialize the engine . . .
# context_rpn <tensorrt.tensorrt.IExecutionContext object at 0x7fd1c323b5f0>
